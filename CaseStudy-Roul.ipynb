# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Pavan-gs/Deloitte_24/main/oj.csv')
df.head()
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5
# 0  0.376927
# 1  0.376927
# 2  0.376927
# ...

# %%
# Q1
df.shape
# Out:
# (28947, 17)

# %%
#Q2 Stucture of dataset
df.size
# Out:
# 492099

# %%
#Q3 Get column names
list(df)
# Out:
# ['store',
#  'brand',
#  'week',
#  'logmove',
#  'feat',
#  'price',
#  'AGE60',
#  'EDUC',
#  'ETHNIC',
#  'INCOME',
#  'HHLARGE',
#  'WORKWOM',
#  'HVAL150',
#  'SSTRDIST',
#  'SSTRVOL',
#  'CPDIST5',
#  'CPWVOL5']

# %%
#Q4 Describe the dataset
df.describe()
# Out:
#               store          week       logmove          feat         price  \
# count  28947.000000  28947.000000  28947.000000  28947.000000  28947.000000
# mean      80.883511    100.459944      9.167864      0.237261      2.282488
# std       35.576511     34.692314      1.019378      0.425411      0.648001
# min        2.000000     40.000000      4.158883      0.000000      0.520000
# 25%       53.000000     70.000000      8.489616      0.000000      1.790000
# 50%       86.000000    101.000000      9.034080      0.000000      2.170000
# 75%      111.000000    130.000000      9.764685      0.000000      2.730000
# max      137.000000    160.000000     13.482016      1.000000      3.870000
#
#               AGE60          EDUC        ETHNIC        INCOME       HHLARGE  \
# count  28947.000000  28947.000000  28947.000000  28947.000000  28947.000000
# mean       0.173130      0.225220      0.155557     10.616735      0.115602
# ...

# %%
#Q5 Convert column names to lowercase
df.columns=df.columns.str.lower()

# %%
#Q6 Fetch the first row 3rd column
df.iloc[0,2] # [row,col]
# Out:
# 40

# %%
# Q7 Fetch the first, second and Third columns of the oj data frame
df.iloc[:,0:3]
# Out:
#        store      brand  week
# 0          2  tropicana    40
# 1          2  tropicana    46
# 2          2  tropicana    47
# 3          2  tropicana    48
# 4          2  tropicana    50
# ...      ...        ...   ...
# 28942    137  dominicks   156
# 28943    137  dominicks   157
# 28944    137  dominicks   158
# 28945    137  dominicks   159
# 28946    137  dominicks   160
#
# [28947 rows x 3 columns]

# %%
# Q8 Fetch the first, second, eighth and the 456th rows of the 1st, third and the sixth columns of the data frame
df.iloc[[0,1,7,455],[2,5]]
# Out:
#      week  price
# 0      40   3.87
# 1      46   3.87
# 7      53   3.29
# 455    51   2.99

# %%
# Q9 Fetch top 5 rows of brand column
df.loc[:,['brand']][:5]
# Out:
#        brand
# 0  tropicana
# 1  tropicana
# 2  tropicana
# 3  tropicana
# 4  tropicana

# %%
# Q10 Fetch top 5 rows of the brand, week and feat details
df.loc[:,['brand','week','feat']][:5]
# Out:
#        brand  week  feat
# 0  tropicana    40     0
# 1  tropicana    46     0
# 2  tropicana    47     0
# 3  tropicana    48     0
# 4  tropicana    50     0

# %% [markdown]
# ## DOUBT Q11

# %%
# Q11.	Fetch the details of all distinct stores
df.drop_duplicates(subset="store")
# Out:
#        store      brand  week   logmove  feat  price     age60      educ  \
# 0          2  tropicana    40  9.018695     0   3.87  0.232865  0.248935
# 330        5  tropicana    40  8.680672     0   3.66  0.117368  0.321226
# 678        8  tropicana    40  9.093357     0   3.19  0.252394  0.095173
# 1032       9  tropicana    40  8.987197     0   3.19  0.269119  0.222172
# 1383      12  tropicana    41  8.822322     0   3.87  0.178341  0.253413
# ...      ...        ...   ...       ...   ...    ...       ...       ...
# 27339    130  tropicana    41  8.070906     0   3.87  0.145117  0.143407
# 27681    131  tropicana    42  8.764053     0   3.66  0.170655  0.271396
# 28029    132  tropicana    40  8.476371     0   3.19  0.139617  0.264528
# 28392    134  tropicana    67  9.071538     0   2.39  0.090153  0.247949
# 28653    137  tropicana    62  9.970024     0   3.87  0.209602  0.528362
#
#          ethnic     income   hhlarge   workwom   hval150   sstrdist   sstrvol  \
# ...

# %%
# Q12.	Fetch all the observations for Tropicana brand using query function
df.query("brand =='tropicana'")
# Out:
#        store      brand  week    logmove  feat  price     age60      educ  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# ...      ...        ...   ...        ...   ...    ...       ...       ...
# 28746    137  tropicana   156  11.313498     1   2.49  0.209602  0.528362
# 28747    137  tropicana   157  10.628133     0   2.66  0.209602  0.528362
# 28748    137  tropicana   158   9.936535     0   3.11  0.209602  0.528362
# 28749    137  tropicana   159  10.855917     1   2.79  0.209602  0.528362
# 28750    137  tropicana   160  10.236525     0   2.88  0.209602  0.528362
#
#         ethnic     income   hhlarge   workwom   hval150  sstrdist   sstrvol  \
# ...

# %%
# Q13 Fetch the columns store, brand and price for observations that belong to the brand tropicana
df.query("brand=='tropicana'")[['store','brand','price']]
# Out:
#        store      brand  price
# 0          2  tropicana   3.87
# 1          2  tropicana   3.87
# 2          2  tropicana   3.87
# 3          2  tropicana   3.87
# 4          2  tropicana   3.87
# ...      ...        ...    ...
# 28746    137  tropicana   2.49
# 28747    137  tropicana   2.66
# 28748    137  tropicana   3.11
# 28749    137  tropicana   2.79
# 28750    137  tropicana   2.88
#
# [9649 rows x 3 columns]

# %%
#Q 14 Fetch bottom 5 observations for those who have bought Tropicana or dominics
df.query("brand in ['tropicana','dominicks']").tail()
# Out:
#        store      brand  week    logmove  feat  price     age60      educ  \
# 28942    137  dominicks   156   7.987524     0   2.00  0.209602  0.528362
# 28943    137  dominicks   157   8.502689     0   1.94  0.209602  0.528362
# 28944    137  dominicks   158   9.505991     0   1.59  0.209602  0.528362
# 28945    137  dominicks   159  10.927376     0   1.49  0.209602  0.528362
# 28946    137  dominicks   160   8.859363     0   1.75  0.209602  0.528362
#
#         ethnic    income   hhlarge   workwom   hval150  sstrdist   sstrvol  \
# 28942  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28943  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28944  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28945  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28946  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
#
#        cpdist5   cpwvol5
# 28942  0.77253  0.333761
# ...

# %%
#Q15 Fetch the income, brand, price observations with Tropicana brand without the feature advertisement (feat ==0)
df.query("brand=='tropicana' and feat==0")[['income','brand','price']]
# Out:
#           income      brand  price
# 0      10.553205  tropicana   3.87
# 1      10.553205  tropicana   3.87
# 2      10.553205  tropicana   3.87
# 3      10.553205  tropicana   3.87
# 4      10.553205  tropicana   3.87
# ...          ...        ...    ...
# 28743  10.966490  tropicana   3.19
# 28745  10.966490  tropicana   2.77
# 28747  10.966490  tropicana   2.66
# 28748  10.966490  tropicana   3.11
# 28750  10.966490  tropicana   2.88
#
# [8045 rows x 3 columns]

# %%
#Q16 Remove the column normInc from the data frame
#df.drop(['normInc'])

# %%
#Q17 Fetch the observations for the tropicana brand excluding the store, price and income fields
df[df['brand']=='tropicana'].drop(['store','price','income'], axis=1)
# Out:
#            brand  week    logmove  feat     age60      educ   ethnic  \
# 0      tropicana    40   9.018695     0  0.232865  0.248935  0.11428
# 1      tropicana    46   8.723231     0  0.232865  0.248935  0.11428
# 2      tropicana    47   8.253228     0  0.232865  0.248935  0.11428
# 3      tropicana    48   8.987197     0  0.232865  0.248935  0.11428
# 4      tropicana    50   9.093357     0  0.232865  0.248935  0.11428
# ...          ...   ...        ...   ...       ...       ...      ...
# 28746  tropicana   156  11.313498     1  0.209602  0.528362  0.11325
# 28747  tropicana   157  10.628133     0  0.209602  0.528362  0.11325
# 28748  tropicana   158   9.936535     0  0.209602  0.528362  0.11325
# 28749  tropicana   159  10.855917     1  0.209602  0.528362  0.11325
# 28750  tropicana   160  10.236525     0  0.209602  0.528362  0.11325
#
#         hhlarge   workwom   hval150  sstrdist   sstrvol  cpdist5   cpwvol5
# ...

# %%
# Q18 Sort the Data in the increasing order of the week
df.sort_values(by='week')
# Out:
#        store        brand  week    logmove  feat  price     age60      educ  \
# 0          2    tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 8141      59  minute.maid    40   7.655391     0   2.62  0.110819  0.233036
# 8025      59    tropicana    40   8.489616     0   3.19  0.110819  0.233036
# 26035    124  minute.maid    40   8.269757     0   3.17  0.119626  0.261876
# 7907      56    dominicks    40   8.565602     1   1.59  0.192889  0.237551
# ...      ...          ...   ...        ...   ...    ...       ...       ...
# 23084    114    dominicks   160   9.034080     0   1.72  0.182173  0.094425
# 16263     92  minute.maid   160  10.455992     1   2.19  0.137828  0.270127
# 4761      45  minute.maid   160   9.987829     1   2.19  0.128857  0.280150
# 22967    114  minute.maid   160  10.815610     1   2.19  0.182173  0.094425
# 28946    137    dominicks   160   8.859363     0   1.75  0.209602  0.528362
#
# ...

# %%
#19 Sort the data in the decreasing order of Income and increasing order of week
df.sort_values(by=["income","week"], ascending=[False, True])
# Out:
#        store        brand  week    logmove  feat  price     age60      educ  \
# 8373      62    tropicana    40   9.373819     0   3.87  0.222534  0.517760
# 8490      62  minute.maid    40   8.449343     0   3.17  0.222534  0.517760
# 8607      62    dominicks    40   8.050703     1   1.59  0.222534  0.517760
# 8374      62    tropicana    41   9.368369     0   3.87  0.222534  0.517760
# 8491      62  minute.maid    41  10.667652     1   1.99  0.222534  0.517760
# ...      ...          ...   ...        ...   ...    ...       ...       ...
# 11724     75  minute.maid   159   8.540910     0   2.64  0.207699  0.219548
# 11842     75    dominicks   159  10.806571     0   1.49  0.207699  0.219548
# 11607     75    tropicana   160   9.114710     0   2.88  0.207699  0.219548
# 11725     75  minute.maid   160  10.747810     1   2.19  0.207699  0.219548
# 11843     75    dominicks   160   9.436998     0   1.71  0.207699  0.219548
#
# ...

# %%
# Q20. Find the mean of the juice price for each brand
df.groupby('brand')['price'].mean()
# Out:
# brand
# dominicks      1.735809
# minute.maid    2.241162
# tropicana      2.870493
# Name: price, dtype: float64

# %%
#Q21.	Find the mean, sum, std of price for every brand
df.groupby('brand')['price'].agg(['mean','sum','std'])
# Out:
#                  mean       sum       std
# brand
# dominicks    1.735809  16748.82  0.385838
# minute.maid  2.241162  21624.97  0.404515
# tropicana    2.870493  27697.39  0.548558

# %%
#Q22. For every brand find the mean price and sum of income
df.groupby('brand').agg(
{
    'price':'mean',
    'income':'sum'
})
# Out:
#                 price         income
# brand
# dominicks    1.735809  102440.872522
# minute.maid  2.241162  102440.872522
# tropicana    2.870493  102440.872522

# %%
#Q23 Find the average income for each brand and at each store
df.groupby(['brand','store'])['income'].mean()
# Out:
# brand      store
# dominicks  2        10.553205
#            5        10.922371
#            8        10.597010
#            9        10.787152
#            12        9.996659
#                       ...
# tropicana  130       9.966650
#            131      10.793537
#            132      10.619154
#            134      10.722518
#            137      10.966490
# Name: income, Length: 249, dtype: float64

# %%
"""24.	Find:
a.	Mean and std deviation of the income
b.	For income greater than or equal to 10.5, find the mean income
c.	For each brand having price >=2.5 find the mean, median, sd of the log of income

"""
print(df['income'].agg(['mean','std']))
# Out:
# mean    10.616735
# std      0.282314
# Name: income, dtype: float64
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 28942    True
# 28943    True
# 28944    True
# 28945    True
# 28946    True
# Name: income, Length: 28947, dtype: bool

# %%
# Q25 25.	Find the Cross tabulation of brands and feature advertisement
pd.crosstab(df['brand'], df['feat'])
# Out:
# feat            0     1
# brand
# dominicks    7169  2480
# minute.maid  6865  2784
# tropicana    8045  1604
